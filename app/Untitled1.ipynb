# %%
import numpy as np
import pandas as pd
import re as re
from settings.constants import *
from sklearn.model_selection import train_test_split

# %%
train = pd.read_csv(TRAIN_CSV, header = 0, dtype={'Age': np.float64})
val  = pd.read_csv(VAL_CSV, header = 0, dtype={'Age': np.float64})
print(TRAIN_CSV)

train.head()
# Out:
# data\train.csv
#    MSSubClass MSZoning  LotFrontage Neighborhood HouseStyle RoofStyle  \
# 0          20       RL         70.0        NAmes     1Story     Gable
# 1          60       RL         59.0      Gilbert     2Story     Gable
# 2          30       RL         67.0      Edwards     1Story     Gable
# 3          50       RL         60.0        SWISU     1.5Fin     Gable
# 4          50       RL         50.0        SWISU     1.5Fin     Gable
#
#   Exterior1st MasVnrType ExterQual Foundation  ...  HeatingQC 2ndFlrSF  \
# 0     MetalSd       None        TA     CBlock  ...         TA        0
# 1     VinylSd       None        Gd      PConc  ...         Gd      772
# 2     MetalSd       None        TA     CBlock  ...         Gd        0
# 3     Wd Sdng    BrkFace        TA     BrkTil  ...         Ex      787
# 4     BrkFace       None        TA     BrkTil  ...         TA      665
#
#    GrLivArea  BsmtFullBath  KitchenQual Fireplaces  GarageType MiscVal  \
# ...

# %%
from utils.dataloader import DataLoader
from utils.dataset import Dataset
from utils.trainer import Estimator
from utils.predictor import Predictor

# %%
x_train, y_train = Dataset(TRAIN_CSV).get_items(None)

x_train.head()
# Out:
#    MSSubClass MSZoning  LotFrontage Neighborhood HouseStyle RoofStyle  \
# 0          20       RL         70.0        NAmes     1Story     Gable
# 1          60       RL         59.0      Gilbert     2Story     Gable
# 2          30       RL         67.0      Edwards     1Story     Gable
# 3          50       RL         60.0        SWISU     1.5Fin     Gable
# 4          50       RL         50.0        SWISU     1.5Fin     Gable
#
#   Exterior1st MasVnrType ExterQual Foundation  BsmtFinSF1 HeatingQC  2ndFlrSF  \
# 0     MetalSd       None        TA     CBlock         922        TA         0
# 1     VinylSd       None        Gd      PConc           0        Gd       772
# 2     MetalSd       None        TA     CBlock           0        Gd         0
# 3     Wd Sdng    BrkFace        TA     BrkTil         569        Ex       787
# 4     BrkFace       None        TA     BrkTil         218        TA       665
#
#    GrLivArea  BsmtFullBath KitchenQual  Fireplaces GarageType  MiscVal  \
# ...

# %%
x_test, y_test = Dataset(VAL_CSV).get_items(None)

# %%
dl = DataLoader()
dl.fit(x_train)
x_train = dl.load_data()

# %%
dl.fit(x_test)
x_test = dl.load_data()

x_train.head()
# Out:
#    LotFrontage  Neighborhood  HouseStyle  RoofStyle  Exterior1st  MasVnrType  \
# 0         70.0            12           2          1            8           2
# 1         59.0             8           5          1           12           2
# 2         67.0             7           2          1            8           2
# 3         60.0            18           0          1           13           1
# 4         50.0            18           0          1            3           2
#
#    ExterQual  Foundation  BsmtFinSF1  HeatingQC  2ndFlrSF  GrLivArea  \
# 0          3           1         922          4         0       1314
# 1          2           2           0          2       772       1571
# 2          3           1           0          2         0        796
# 3          3           0         569          0       787       1768
# 4          3           0         218          4       665       1691
#
#    BsmtFullBath  KitchenQual  Fireplaces  GarageType  MiscVal
# ...

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
# model = RandomForestRegressor().fit(x_train, y_train)
model = Estimator().fit(x_train, y_train)

# %%
import pickle
with open('models/model.pickle', 'wb')as f:
    pickle.dump(model, f)

# %%
model.score(x_test, y_test)
# Out:
# 0.8523446057293507

# %%
model.score(x_train, y_train)
# Out:
# 0.9743697646445197

# %%
Predictor().predict(x_test)
# Out:
# array([138988.        , 308778.16      , 106206.49      , 182001.        ,
#        276637.26      ,  95884.5       , 223452.94      , 144498.35      ,
#         79807.5       , 113584.        , 134024.5       , 119535.5       ,
#        105377.        , 202788.55      , 164736.        , 138208.        ,
#        200877.5       , 145039.        , 101998.83      , 233655.22      ,
#        168819.8       , 193400.75      , 177292.41      , 117620.        ,
#        188238.53      , 182434.65      , 184140.29      , 106886.        ,
#        164015.87      , 198753.69      , 109343.35      , 259083.5       ,
#        276898.2       , 111511.5       , 246261.99      , 147769.        ,
#        147073.84      , 204178.6       , 298881.81      , 109048.16666667,
#        114809.83      , 241730.45      , 116908.08      , 357308.21      ,
#        134477.1       , 135480.13      , 117102.5       , 134687.5       ,
# ...
